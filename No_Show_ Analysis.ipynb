# %% [markdown]
# # **Project: Investigate a Dataset - No_show_appointments**
#
# ## *Table of Contents*
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# ## Introduction
#
# ### Dataset Description
#
# No_Show_Apppointment dataset provides information from 65,535 appointments made in Brazil with 14 variables. Mainly focuses on the question of whether patients who make appointments actually show up for the appointments they make. We have in the dataset the patient's ID which is the  identification of each patient,Neighbourhood which gives the information of whether the hospital is located at,We have ScheduleDay which tells dey when the patient set up the appointment,Scholarship which indicates whether the patient is a beneficiary of the brasilian welfare program(Bolsa Familia).
# AppointmentID is the identification of each patient for appointment. SMS_received show whether the patient received any message to make the appointment.
# Gender is another variable in our dataset and age of the patient.The diseases the patients have are also variables such as Diabetes,Hipertension,Alcoholism, and handcap.Which have values 1 for true and 0 for false. Appointment Day is when the patient had scheduled the appointment to take place. No_ show is also a variable which shows whether the patient showed up for the appointment made or not. With No implying that the patient showed up for the appointment and Yes implying that the patient did not show up for the appointment.
#
#
# ### Question(s) for Analysis
# 1. Do the diseases that the patients have contribute to the number of patients that show up for appointments made?
# 2. Does gender contribute to the number of patients showing up for appointments?
# 3. Does the scholarship relate to the number of No_shows?
# 4. Is there a relation between SMS_received and Number of No_shows?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Upgrade pandas to use dataframe.explode() function. 
# !pip install --upgrade pandas==0.25.0
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\USER\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\USER\\AppData\\Local\\Temp\\pip-install-l92qa032\\pandas_b45ff5e1535f45da952249d566152a6e\\setup.py'"'"'; __file__='"'"'C:\\Users\\USER\\AppData\\Local\\Temp\\pip-install-l92qa032\\pandas_b45ff5e1535f45da952249d566152a6e\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\USER\AppData\Local\Temp\pip-wheel-7xxk69gg'
#        cwd: C:\Users\USER\AppData\Local\Temp\pip-install-l92qa032\pandas_b45ff5e1535f45da952249d566152a6e\
#   Complete output (907 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\pandas
# ...

# %% [markdown]
# # **DATA WRANGLING**

# %%
df=pd.read_excel(r"C:\Users\USER\Desktop\ALX\No_Show_Appointments.xls")
# Out:
#   copying pandas\tests\indexes\timedeltas\test_formats.py -> build\lib.win-amd64-3.8\pandas\tests\indexes\timedeltas
#   copying pandas\tests\indexes\timedeltas\test_indexing.py -> build\lib.win-amd64-3.8\pandas\tests\indexes\timedeltas
#   copying pandas\tests\indexes\timedeltas\test_ops.py -> build\lib.win-amd64-3.8\pandas\tests\indexes\timedeltas
#   copying pandas\tests\indexes\timedeltas\test_partial_slicing.py -> build\lib.win-amd64-3.8\pandas\tests\indexes\timedeltas
#   copying pandas\tests\indexes\timedeltas\test_scalar_compat.py -> build\lib.win-amd64-3.8\pandas\tests\indexes\timedeltas
#   copying pandas\tests\indexes\timedeltas\test_setops.py -> build\lib.win-amd64-3.8\pandas\tests\indexes\timedeltas
#   copying pandas\tests\indexes\timedeltas\test_timedelta.py -> build\lib.win-amd64-3.8\pandas\tests\indexes\timedeltas
#   copying pandas\tests\indexes\timedeltas\test_timedelta_range.py -> build\lib.win-amd64-3.8\pandas\tests\indexes\timedeltas
# ...

# %%
df.head(10)

# %%
df.tail(15)
# Out:
#     creating build\lib.win-amd64-3.8\pandas
#     copying pandas\conftest.py -> build\lib.win-amd64-3.8\pandas
#     copying pandas\testing.py -> build\lib.win-amd64-3.8\pandas
#     copying pandas\_typing.py -> build\lib.win-amd64-3.8\pandas
#     copying pandas\_version.py -> build\lib.win-amd64-3.8\pandas
#     copying pandas\__init__.py -> build\lib.win-amd64-3.8\pandas
#     creating build\lib.win-amd64-3.8\pandas\api
#     copying pandas\api\__init__.py -> build\lib.win-amd64-3.8\pandas\api
#     creating build\lib.win-amd64-3.8\pandas\arrays
#     copying pandas\arrays\__init__.py -> build\lib.win-amd64-3.8\pandas\arrays
#     creating build\lib.win-amd64-3.8\pandas\compat
#     copying pandas\compat\chainmap.py -> build\lib.win-amd64-3.8\pandas\compat
#     copying pandas\compat\pickle_compat.py -> build\lib.win-amd64-3.8\pandas\compat
#     copying pandas\compat\_optional.py -> build\lib.win-amd64-3.8\pandas\compat
# ...

# %%
#The datatypes of the variables
df.dtypes

# %%
df.describe()

# %%
df.info()

# %%
#Number of columns
len(df.axes[1])

# %%
# Number of rows/samples
len(df.axes[0])

# %%
# View missing values count for each variable
df.isnull().sum() # There are no misssing values in the dataset

# %%
# View number of duplicates in the dataset
df.duplicated().sum()

# %% [markdown]
# ###### There are no duplicates and null values

# %%
df['PatientId'].duplicated().sum()

# %%
df.describe()

# %%
df.shape

# %%
df.info()

# %%
df['PatientId'].nunique()

# %%
df['AppointmentID'].nunique()

# %%
df.nunique()

# %%
df.drop_duplicates()

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
#  ### **The dataset has no duplicates and null values that need to be dropped.The number of records for each variable is 65535 meaning the number of records are there for every variable**.

# %% [markdown]
# ### The ScheduledDay and AppointmentDay are supposed to be in datetime datatypes and not object.

# %%
#Incorrect datatypes
df['ScheduledDay']=pd.to_datetime(df['ScheduledDay'])

# %%
# To change Appointment datatype from object to datetime
df['AppointmentDay']=pd.to_datetime(df['AppointmentDay'])

# %%
# View changes
df.dtypes

# %% [markdown]
# ### Changing the column name hipertension to hypertension

# %%
df=df.rename(columns= {'Hipertension':'Hypertension'})

# %%
#View changes
df.dtypes

# %% [markdown]
# ### Changing column name handcap to handicap

# %%
df=df.rename(columns= {'Handcap':'Handicap'})

# %% [markdown]
# ### Changing column name No-show to No_show

# %%
df=df.rename(columns={'No-show':'No_show'})

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
#
# # Do the diseases that the patients have contribute to the number of patients that show up for appointments.
#
# ### Hypertension

# %%
df_F=df[df['No_show']=='Yes']

# %%
print(df_F)

# %%
#To get number of patients who showed up for their appointments
df_N=df[df['No_show']=='No']
print(df_N)

# %% [markdown]
# ### Of the 65,535 appointments made only 51,614 patients showed up for their appointment and 13,921 didn't show up

# %%
df.hist(figsize=(8,8))

# %% [markdown]
# ###### Both AppointmentID and ScheduledDay are skewed to the left

# %%
df['Hypertension'].groupby(df['No_show']).value_counts().unstack() #1 stands for patients with hypertension and 0 for patients 
#without.

# %%
df['Hypertension'].plot(kind='hist', title='Number of patients with and without Hypertension');
plt.xlabel('0.0 REP No, 1.0 REP Yes')
plt.ylabel('Number of patients with hypertension')

# %% [markdown]
# #### There are 12,709 patients with hypertension who made appointments.There are 10,400 patients with hypertension who showed up for the made appointment with 2309 patients who had hypertension not showing up for the appointment.

# %% [markdown]
# ### Diabetes

# %%
df['Diabetes'].groupby(df['No_show']).value_counts().unstack()

# %% [markdown]
# ### There are 3,638 patients with diabetes who showed up for the made appointments, with 851 patients with diabetes not showing up for the made appointment. Of the total 4,489 patients with diabetes who had scheduled an appointment.

# %% [markdown]
# ### Handicap

# %%
df['Handicap'].groupby(df['No_show']).value_counts().unstack()

# %% [markdown]
# ### There are 1085 patients who are handcapped who showed up with 267 not showing up for the made appointments.

# %% [markdown]
# ### Alcoholism

# %%
df['Alcoholism'].groupby(df['No_show']).value_counts().unstack()

# %% [markdown]
# ### Of the 2,086 patients affected by alcoholism only 1,663 showed up for the scheduled appointment with 423 patients not showing up.

# %% [markdown]
# ### The number of patients showing up for the scheduled appointments was influenced by the disease a patient was suffering from with hypertension having the most patients showing up for the scheduled appointments and handicapped patients having the least number of patients who show up for the scheduled apppointments.

# %% [markdown]
# # Does gender contribute to the numbers of patients showing up for appointments?

# %%
#df['No-show']=df['No-show'].map({'Yes':1,'No':0})

# %%
#df.groupby(['Gender','No-show'],as_index=False)[].sum()

# %%
#df.groupby(['Gender','No-show'],as_index=False)['No-show':'Yes'].sum()

# %%
#df.groupby(['Gender','No-show'],as_index=False)['df_N'].sum()

# %%
df['Gender'].value_counts().plot(kind='barh',title='Number of patient appointments by gender')
def addlabels(x,y):
    #for i in range(len(y)):
       # plt.text(i, y[i], y[i], ha = 'center',va='bottom')
  
## if __name__ == '__main__':
    for i, v in enumerate(y):
           ax.text(v + 3, i + .25, str(v),
                   color = 'red', fontweight = 'bold')

plt.xlabel('Number of appointments')
plt.ylabel('Gender')

# %% [markdown]
# ### Women made more appointments than men.

# %%
df.groupby(['Gender','No_show'],as_index=False)['AppointmentID'].count()

# %%
df.groupby('Gender')['No_show'].value_counts(normalize=True).mul(100).unstack('Gender')

# %%
df['Gender'].value_counts().plot(kind='pie',title='percentage of males and females',figsize=(5,5),autopct="%2.1f%%")
#def func(pct, allvalues):
    #absolute = int(pct / 100.*np.sum(allvalues))
    #return "{:.1f}%\n({:d} g)".format(pct, absolute)
 
plt.legend()

# %% [markdown]
# ### Of the 65535 appointments made  42,253 apppointments were made by females and 23,282 appointments were made by males.64.5% of the females made the appointments while only 35.5% of males made the appointments.

# %%
#df2=['Scholarship','Hypertension','Diabetes','Alcoholism','Handicap','SMS_received']
df2=['Hypertension','Diabetes','Alcoholism','Handicap']

print(df2)

# %%
df.groupby(['Gender','No_show'],as_index=False)[df2].sum()

# %% [markdown]
# ### The number of females and males who show up for the apppointments is more than those who don't show up for each diagnosis. More women than men show up for the appointments in all the diagnosis except for alcoholism where more men have made appointments and more show up for appointments.

# %% [markdown]
# ###  78.53% of the women that made appointments  showed up for ther the appointments with 79.16% of the men who made appointments showing up for the appointments. This shows that men are more concerned with their health than women.

# %% [markdown]
# # Is there a relation between SMS_received and No_show

# %%
df['SMS_received'].groupby(df['No_show']).value_counts().unstack()

# %%
df['SMS_received'].plot(kind='box');

# %%
df['SMS_received'].plot(kind='hist', title ='Number of patients who received an SMS',xlabel='If SMS_received', ylabel='Frequency of patients')
plt.xlabel('0.0 REP No, 1.0 REP Yes')
plt.ylabel('Frequency of patients')

# %%
df['SMS_received'].value_counts().plot(kind='pie',title='SMS_ received(1=Yes,0=No)',figsize=(5,5),autopct="%2.1f%%")
plt.legend()

# %% [markdown]
# ### Of the 65,535 appointments done only 19,503 patients received an SMS which is 29.8% of the total appointments made and 46,032 patients did not receive an SMS which is 70.2% of the total appointments made. Of the 19,503 patients that received an sms 13,999 patients showed up for the appointments and 5,504 did not show up for the appointment done.
#
# ### 71.8% of the patients showed up for the appointment made with 28.2% of the patients not showing up for the appointments done even after receiving the SMS.
#
# ### 81.7% of those who did not receive the SMS showed up for their appointments with 18.3% of those who did not receive the SMS nort showing up for the appointments.

# %% [markdown]
# ### Of the 51,614 patients that had showed up for appointment only 27.1% of them had received the SMS and 72.9% of them had not received the SMS

# %% [markdown]
# # Does the scholarship relate to the number of No_shows

# %%
df['Scholarship'].groupby(df['No_show']).value_counts().unstack()

# %%
df['Scholarship'].value_counts().plot(kind='pie',title ='Percentage of patients with and without scholarship',figsize=(5,5),autopct="%2.1f%%")
plt.legend()

# %% [markdown]
# ##### Of the 65,535 patients who made an appointment 10% have a scholarship and 90% don't have a scholarship.

# %% [markdown]
# ### Of the 6,580 patients who have scholarship 74.3% of them showed up for the appointment made and 25.7% of them didn't show up for the appointments made.

# %%
df.plot(x='No_show',y='Scholarship',kind=('scatter'))

# %% [markdown]
# ### There is no correlation between patients with scholarship and showing up for apppointments made.

# %% [markdown]
# >
# ## Conclusions
# ##### There were 65535 appointments made with 14 variables. There are no duplicate and null values in the dataset. The maximum age of the patients that made appointments is 115 yeras with the least age being 0. The mean age of patients that made appointments is 36.57.
#
#
# ###### Of the 65,535 appointments made only 51,614 patients showed up for their appointment and 13,921 didn't show up.
#
# ###### The number of patients showing up for the scheduled appointments was influenced by the disease a patient was suffering from with hypertension having the most patients showing up for the scheduled appointments and handicapped patients having the least number of patients who show up for the scheduled apppointments.
#
# ##### The number of females and males who show up for the apppointments is more than those who don't show up for each diagnosis. More women than men show up for the appointments in all the diagnosis(i.e Diabetes,Hypertension and Handicap) except for alcoholism where more men have made appointments and more show up for appointments made than women.
# ##### Women are more concerned about their health status than men.
#
# #####  78.53% of the women that made appointments  showed up for ther the appointments with 79.16% of the men who made appointments showing up for the appointments. This shows that men are more concerned with their health than women.
#
# #####  Of the 6,580 patients who have scholarship 74.3% of them showed up for the appointment made and 25.7% of them didn't show up for the appointments made.There is no correlation between a patients under scholarship and  them showing up for appointments made.
#
# ##### Of the 51,614 patients that had showed up for appointment only 27.1% of them had received the SMS and 72.9% of them had not received the SMS.Receiving an SMS does not contribute greately to the number of patients showing up for the appointments done.
#
# ##### Even after receiving the SMS 28.2% of the patients did not show up for their appointments.
#
#
# ##### One limitation of my exploration is that the scatter plots are not clear enough since the data values are only 2 for most of the variables.
#
#
#
# ## Submitting your Project

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
